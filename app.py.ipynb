# %%
import streamlit as st
import joblib
import pandas as pd


# Load trained model

@st.cache_resource
def load_model():
    model = joblib.load("Linear_Regression.joblib")
    preprocessor = joblib.load("preprocessor.joblib")
    return model, preprocessor

model, preprocessor = load_model()




# Page Title

st.title("House Price Prediction")

st.write("Enter Your House Information To Predict Price")



# Create two columns

col1, col2 = st.columns(2)


# Inputs - Column 1


with col1:


    bedrooms = st.number_input(
        "Bedrooms",
        min_value=1,
        max_value=5,
        value=2
    )

    bathrooms = st.number_input(
        "Bathrooms",
        min_value=1,
        max_value=5,
        value=2
    )

    area_sqft = st.number_input(
        "Area_sqft",
        min_value=200,
        max_value=4000,
        value=1500
    )

    lot_size = st.number_input(
        "Lot_Size",
        min_value=400,
        max_value=7500,
        value=2500
    )

    floors = st.number_input(
        "Floors",
        min_value=1,
        max_value=3,
        value=2
    )

    house_age = st.number_input(
        "House_Age",
        min_value=0,
        max_value=40,
        value=19
    )

    garage_capacity = st.number_input(
        "Garage_Capacity",
        min_value=0,
        max_value=3,
        value=0
    )

    distance_to_city = st.number_input(
        "Distance_to_City",
        min_value=1,
        max_value=50,
        value=25
    )

    crime_rate = st.number_input(
        "Crime_Rate",
        min_value=0.0,
        max_value=15.0,
        value=7.0
    )

    school_rating = st.number_input(
        "School_Rating",
        min_value=1.0,
        max_value=5.0,
        value=2.5
    )


# Inputs column 2


with col2:

    city = st.selectbox(
        "City",
        options=("Thane", "Nashik", "Mumbai", "Nagpur", "Pune"),
        index=None,
        placeholder="Select City ?"
    )

    neighborhood = st.selectbox(
        "Neighborhood",
        options=("Thane", "Nashik", "Mumbai", "Nagpur", "Pune"),
        index=None,
        placeholder="Select Neighborhood ?"
    )

    property_type = st.selectbox(
        "Property_Type",
        options=("Independent House", "Apartment", "Villa"),
        index=None,
        placeholder="Select Property Type ?"
    )

    has_garden = st.selectbox(
        "Has_Garden",
        options=(True, False),
        index=None,
        placeholder="Select Has Garden ?"
    )

    has_pool = st.selectbox(
        "Has_Pool",
        options=(True, False),
        index=None,
        placeholder="Select Has Pool ?"
    )

    condition = st.selectbox(
        "Condition",
        options=("Poor", "Fair", "Good", "Excellent"),
        index=None,
        placeholder="Select Condition ?"
    )

    heating_type = st.selectbox(
        "Heating_Type",
        options=("Gas", "Solar", "Electric"),
        index=None,
        placeholder="Select Heating Type ?"
    )


# Prediction Button

if st.button("Predict"):

    # Check mandatory fields

    if (  city is None
        or neighborhood is None
        or property_type is None
        or has_garden is None
        or has_pool is None
        or condition is None
        or heating_type is None
    ):

        st.error("Each Field is Mandatory")

    else:

        # Create DataFrame

        features = pd.DataFrame([{
           "City": city,
           "Neighborhood": neighborhood,
           "Property_Type": property_type,
           "Bedrooms": bedrooms,
           "Bathrooms": bathrooms,
           "Area_sqft": area_sqft,
           "Lot_Size": lot_size,
           "Floors": floors,
           "House_Age": house_age,
           "Garage_Capacity": garage_capacity,
           "Distance_to_City": distance_to_city,
           "Crime_Rate": crime_rate,
           "School_Rating": school_rating,
           "Has_Garden": has_garden,
           "Has_Pool": has_pool,
           "Condition": condition,
           "Heating_Type": heating_type


        }])

        # Prediction

        


        features = preprocessor.transform(features)

        prediction = model.predict(features)

        predicted_price = prediction[0]


        
        # Display Result
        

        st.success(
            f"Predicted House Price: ₹{predicted_price:,.2f}"
        )
# Out:
# 2026-08-18 22:01:16.812 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:01:59.824 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:24.659
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\Users\AL FARES\Desktop\coding\pythonintership\.venv\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-08-18 22:02:25.085 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.087 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.089 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.090 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.092 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.106 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.108 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.119 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.121 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.123 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.124 Session state does not function when running a script without `streamlit run`
# 2026-08-18 22:02:25.126 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.134 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.135 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.137 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.140 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.142 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.143 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.154 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.156 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.157 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.171 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.172 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.175 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.177 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.186 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.187 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.189 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.190 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.192 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.193 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.256 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.259 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.276 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.284 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.286 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.292 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.305 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.307 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.309 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.316 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.319 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.321 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.322 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.324 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.326 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.334 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.335 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.337 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.339 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.340 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.342 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.343 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.353 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.354 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.356 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.357 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.359 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.368 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.369 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.372 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.821 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.822 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.823 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.824 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.825 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.826 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.832 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.833 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.834 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.835 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.836 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.837 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.838 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.839 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.840 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.842 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.843 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.850 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.851 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.852 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.853 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.854 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.855 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.856 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.858 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.859 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.860 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.867 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.868 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.869 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.870 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.871 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.873 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-08-18 22:02:25.875 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
