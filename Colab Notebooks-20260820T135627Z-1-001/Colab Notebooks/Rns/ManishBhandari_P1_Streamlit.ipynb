# %% [markdown]
# # House Price Prediction – Streamlit App
# Linear Regression project based on the supplied `ManishBhandari.P1.html` notebook.

# %%
# Install required packages
# !pip install -q streamlit pandas numpy matplotlib scikit-learn

# %%
# Upload your CSV dataset (house_price_dataset.csv) in Colab/Jupyter before running the Streamlit app.
from google.colab import files
uploaded = files.upload()

# %%
# Save/run the Streamlit app.
# First upload house_price_streamlit.py to the same runtime folder.
# !streamlit run house_price_streamlit.py
