# %%
# !pkill -f streamlit

# %%
# !streamlit run app.py --server.port 8503 --server.enableCORS false --server.enableXsrfProtection false &e &
# Out:
# /bin/bash: line 1: streamlit: command not found
# /bin/bash: line 1: e: command not found

# %%
from google.colab import output

output.serve_kernel_port_as_iframe(8503)
