# %%
import pandas as pd
import numpy as np

# %%
dict1 = {
    "name": ["manish", "rohit", "saurabh", "om","sarthak"],
    "marks": [92, 34, 24, 17, 88],
    "city": ["rampur", "kolkata", "bareilly", "antarctica", "dubai"]
}

# %%
df = pd.DataFrame(dict1)

# %%
print(df)
# Out:
#       name  marks        city
# 0   manish     92      rampur
# 1    rohit     34     kolkata
# 2  saurabh     24    bareilly
# 3       om     17  antarctica
# 4  sarthak     88       dubai

# %%
df.head(5)
# Out:
#       name  marks        city
# 0   manish     92      rampur
# 1    rohit     34     kolkata
# 2  saurabh     24    bareilly
# 3       om     17  antarctica
# 4  sarthak     88       dubai

# %%
df.tail(5)
# Out:
#       name  marks        city
# 0   manish     92      rampur
# 1    rohit     34     kolkata
# 2  saurabh     24    bareilly
# 3       om     17  antarctica
# 4  sarthak     88       dubai

# %%
df.to_csv("cat.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1036/2332454328.py in <cell line: 0>()
# ----> 1 df.to_csv("cat.csv")
#
# NameError: name 'df' is not defined
